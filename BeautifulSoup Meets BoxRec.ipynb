# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

# %%
url = 'https://boxrec.com/en/proboxer/704891'
source = requests.get(url)
content = source.content
soup = bs(content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="pro boxer" name="description"/>
# <title>BoxRec: Camilo Prieto</title>
# <link href="https://boxrec.com/en/proboxer/704891" rel="canonical"/>
# <link href="/build/images/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/build/images/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/build/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/build/images/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/build/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/build/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# ...

# %%
# Out:
# [                                           Unnamed: 0  ...                                        Unnamed: 10
# 0                                                 NaN  ...                                                NaN
# 1                                                 NaN  ...                                                NaN
# 2   interim World Boxing Council FECARBOX Light Title  ...  interim World Boxing Council FECARBOX Light Title
# 3                                                 NaN  ...                                                NaN
# 4                                                 NaN  ...                                                NaN
# 5                                                 NaN  ...                                                NaN
# 6                                                 NaN  ...                                                NaN
# ...
